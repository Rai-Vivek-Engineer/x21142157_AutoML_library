# %%
from google.colab import drive
drive.mount('/gdrive/')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive/; to attempt to forcibly remount, call drive.mount("/gdrive/", force_remount=True).
# /gdrive

# %%
import py_TransferLearning_Package
import cv2

# %%
## Read the data
import numpy as np
X = np.load('/content/drive/MyDrive/AutoML Library/Dataset/ct_data.npy')
y = np.load('/content/drive/MyDrive/AutoML Library/Dataset/ct_labels.npy')

# %%
resized_images = np.empty((X.shape[0], 48, 48, 3))

# Loop through each image and resize it
for i in range(X.shape[0]):
    resized_images[i] = cv2.resize(X[i], (48, 48))

# %%
Y  = np.array(y)

# %%
num_unique_values = len(np.unique(Y))
labels = np.eye(num_unique_values)[Y]
print(labels)
# Out:
# [[0. 1.]
#  [0. 1.]
#  [0. 1.]
#  ...
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]]

# %%
performance_table = py_TransferLearning_Package.modeling(resized_images,labels,2,32,20)
# Out:
# ...
# 80134624/80134624 [==============================] - 4s 0us/step
# Epoch 1/20
# 15/15 [==============================] - 19s 201ms/step - loss: 0.6311 - accuracy: 0.7152 - val_loss: 0.5954 - val_accuracy: 0.7273 - lr: 1.0000e-04
# Epoch 2/20
# 15/15 [==============================] - 1s 82ms/step - loss: 0.5706 - accuracy: 0.7316 - val_loss: 0.5997 - val_accuracy: 0.7091 - lr: 1.0000e-04
# Epoch 3/20
# 15/15 [==============================] - 2s 96ms/step - loss: 0.5873 - accuracy: 0.7275 - val_loss: 0.5547 - val_accuracy: 0.7273 - lr: 1.0000e-04
# Epoch 4/20
# 15/15 [==============================] - 2s 135ms/step - loss: 0.5504 - accuracy: 0.7275 - val_loss: 0.5461 - val_accuracy: 0.7273 - lr: 1.0000e-04
# Epoch 5/20
# 15/15 [==============================] - 2s 104ms/step - loss: 0.5408 - accuracy: 0.7439 - val_loss: 0.4589 - val_accuracy: 0.7636 - lr: 1.0000e-04
# Epoch 6/20
# ...

# %%
performance_table
# Out:
#                  Accuracy  Precision    Recall  F1 Score
# Model
# VGGNet19         0.800000   0.796167  0.800000  0.797786
# MobileNetV2      0.781818   0.770563  0.781818  0.752066
# DenseNet-121     0.763636   0.821612  0.763636  0.689782
# ResNet50         0.727273   0.528926  0.727273  0.612440
# EfficientNet-B7  0.727273   0.528926  0.727273  0.612440
